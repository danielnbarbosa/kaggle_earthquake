# %% [markdown]
# ## ABOUT
#
# - increased image size to 392
# - reduced batch size
# - remove early stopping and lr plataeu callbacks (causing problems with lr find)
# - shuffling training/validation data, as test set is not contiguous
# - added more results visualizations
# - not using sigmoid as final activation
# ---
# - Best MAE: 2.15
# - LB Score: 1.689

# %% [markdown]
# ## SETUP

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai
from fastai.vision import *
from fastai.callbacks import *

# %%
# show versions
print('fastai:', fastai.__version__)
print('pytorch:', torch.__version__)
print('python:', sys.version.split(' ')[0])
# Out:
# fastai: 1.0.49
# pytorch: 1.0.1.post2
# python: 3.6.7

# %%
version = 'v8'       # this should match the notebook filename

seed = 42
arch = models.resnet50
size = 392
bs = 16
num_workers = 6     # set to available cores

scale = 1           # number to divide y by to help normalize values
transform = 'spectogram'  # which time series to visual transformation to use

# %%
# set seed
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# ## DATA

# %% [markdown]
# Assumes the following has been generated using `gen_spectogram`:
# - `X_train.csv`
# - `y_train.csv`
# - `train_images`
# - `test_images`

# %%
# set paths
path = pathlib.Path.home()/'.fastai/data/kaggle_earthquake'
img_path = path/f'train_images/{transform}'
save_path = path/'saved_models'
os.makedirs(save_path, exist_ok=True)

# %%
# load segment CSVs
#pd.options.display.precision = 15
X_train = pd.read_csv(path/'X_train.csv', index_col=0)
y_train = pd.read_csv(path/'y_train.csv', index_col=0)

# %%
#X_train.head()

# %%
y_train.head()
# Out:
#    time_to_failure
# 0         1.430797
# 1         1.391499
# 2         1.353196
# 3         1.313798
# 4         1.274400

# %%
# graph y_train
print('min:', min(y_train['time_to_failure']))
print('max:', max(y_train['time_to_failure']))
plt.figure()
plt.plot(y_train)
# Out:
# min: 0.0063976571678
# max: 16.103195567

# %% [markdown]
# ## MODEL

# %%
# scale down the labels
def gen_label(path):
    id = int(path.name.split('_')[1].split('.')[0])
    ttf = y_train.iloc[id]['time_to_failure']
    return ttf / scale

# %%
gen_label(img_path/'seg_0.png')
# Out:
# 1.4307971859

# %%
# no data augmentation
tfms = get_transforms(do_flip=False, p_affine=0., p_lighting=0.)

# %%
fake_label = 0.
#valid_idx = range(3000, len(y_train))

src = (ImageList.from_folder(img_path)
        .split_by_rand_pct(valid_pct=0.20)
        .label_from_func(gen_label, label_cls=FloatList)
        .add_test_folder(f'../../test_images/{transform}', label=fake_label))

# %%
data = (src.transform(tfms, resize_method=ResizeMethod.SQUISH, size=size)
        .databunch(bs=bs, num_workers=num_workers)
        .normalize(imagenet_stats))

# %%
# verify datasets loaded properly
n_train_items = len(data.train_ds)
n_valid_items = len(data.valid_ds)
n_test_items = len(data.test_ds)

print('train: ', n_train_items)
print('valid: ', n_valid_items)
print('test:  ', n_test_items)
print('')
print('TOTAL: ', n_train_items + n_valid_items + n_test_items)
# Out:
# train:  3356
# valid:  838
# test:   2624
#
# TOTAL:  6818

# %%
# verify images and labels match up
data.show_batch(4, figsize=(9, 9))

# %%
# define metrics
def mae_scaled(preds, targs):
    return mean_absolute_error(preds.view(-1)*scale, targs.view(-1)*scale)

def mse_scaled(preds, targs):
    return mean_squared_error(preds.view(-1)*scale, targs.view(-1)*scale)

# %%
# L1 loss is sum of the all the absolute differences
# more robust to outliers
l1loss = nn.L1Loss()
def l1_loss(preds, targs):
    return l1loss(preds.view(-1), targs.view(-1))

# L2 loss is sum of the all the squared differences
# less robust to outliers
l2loss = nn.MSELoss()
def l2_loss(preds, targs):
    return l2loss(preds.view(-1), targs.view(-1))

# %%
# return correct size of fully connected layer based on pre-trained model
def final_conv_layer_size(arch):
    if arch == models.resnet18 and size == (217, 223): return 512*14*21
    elif arch == models.resnet34 and size == (217, 223): return 512*7*7  
    elif arch == models.resnet50 and size == (217, 223): return 2048*7*7
    elif arch == models.resnet50 and size == 224: return 2048*7*7
    elif arch == models.resnet50 and size == 392: return 2048*13*13

# %%
# define custom heads
small_head = nn.Sequential(Flatten(), nn.Linear(final_conv_layer_size(arch), 1))

small_head_sigmoid = nn.Sequential(Flatten(), nn.Linear(final_conv_layer_size(arch), 1),  nn.Sigmoid())

medium_head = nn.Sequential(
  nn.AvgPool2d(13, 13),
  Flatten(), 
  nn.BatchNorm1d(2048),
  nn.Dropout(0.5),
  nn.Linear(2048, 256),
  nn.ReLU(),
  nn.BatchNorm1d(256),
  nn.Dropout(0.5),
  nn.Linear(256, 1))

big_head = nn.Sequential(
  nn.AvgPool2d(13, 13),
  Flatten(), 
  nn.BatchNorm1d(2048),
  nn.Dropout(0.5),
  nn.Linear(2048, 512),
  nn.ReLU(),
  nn.BatchNorm1d(512),
  nn.Dropout(0.5),
  nn.Linear(512, 128),
  nn.ReLU(),
  nn.BatchNorm1d(128),
  nn.Dropout(0.5),
  nn.Linear(128, 1))


big_head_sigmoid = nn.Sequential(
  nn.AvgPool2d(13, 13),
  Flatten(), 
  nn.BatchNorm1d(2048),
  nn.Dropout(0.5),
  nn.Linear(2048, 512),
  nn.ReLU(),
  nn.BatchNorm1d(512),
  nn.Dropout(0.5),
  nn.Linear(512, 128),
  nn.ReLU(),
  nn.BatchNorm1d(128),
  nn.Dropout(0.5),
  nn.Linear(128, 1),
  nn.Sigmoid())

# %%
# create learner
learn = cnn_learner(data, arch,
                    custom_head=big_head,
                    loss_func=l1_loss,
                    metrics=[mean_squared_error, mean_absolute_error, mse_scaled, mae_scaled])

# %%
print(learn.summary())
# Out:
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [1, 64, 196, 196]    9,408      False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 196, 196]    128        True
# ______________________________________________________________________
# ReLU                 [1, 64, 196, 196]    0          False
# ______________________________________________________________________
# MaxPool2d            [1, 64, 98, 98]      0          False
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      4,096      False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      36,864     False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 256, 98, 98]     16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 98, 98]     512        True
# ______________________________________________________________________
# ReLU                 [1, 256, 98, 98]     0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 98, 98]     16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 98, 98]     512        True
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      36,864     False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 256, 98, 98]     16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 98, 98]     512        True
# ______________________________________________________________________
# ReLU                 [1, 256, 98, 98]     0          False
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 64, 98, 98]      36,864     False
# ______________________________________________________________________
# BatchNorm2d          [1, 64, 98, 98]      128        True
# ______________________________________________________________________
# Conv2d               [1, 256, 98, 98]     16,384     False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 98, 98]     512        True
# ______________________________________________________________________
# ReLU                 [1, 256, 98, 98]     0          False
# ______________________________________________________________________
# Conv2d               [1, 128, 98, 98]     32,768     False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 98, 98]     256        True
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     147,456    False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 512, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 49, 49]     1,024      True
# ______________________________________________________________________
# ReLU                 [1, 512, 49, 49]     0          False
# ______________________________________________________________________
# Conv2d               [1, 512, 49, 49]     131,072    False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 49, 49]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     147,456    False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 512, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 49, 49]     1,024      True
# ______________________________________________________________________
# ReLU                 [1, 512, 49, 49]     0          False
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     147,456    False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 512, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 49, 49]     1,024      True
# ______________________________________________________________________
# ReLU                 [1, 512, 49, 49]     0          False
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 128, 49, 49]     147,456    False
# ______________________________________________________________________
# BatchNorm2d          [1, 128, 49, 49]     256        True
# ______________________________________________________________________
# Conv2d               [1, 512, 49, 49]     65,536     False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 49, 49]     1,024      True
# ______________________________________________________________________
# ReLU                 [1, 512, 49, 49]     0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 49, 49]     131,072    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 49, 49]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    524,288    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 256, 25, 25]     589,824    False
# ______________________________________________________________________
# BatchNorm2d          [1, 256, 25, 25]     512        True
# ______________________________________________________________________
# Conv2d               [1, 1024, 25, 25]    262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1, 1024, 25, 25]    2,048      True
# ______________________________________________________________________
# ReLU                 [1, 1024, 25, 25]    0          False
# ______________________________________________________________________
# Conv2d               [1, 512, 25, 25]     524,288    False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 25, 25]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 512, 13, 13]     2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 13, 13]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 2048, 13, 13]    1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [1, 2048, 13, 13]    4,096      True
# ______________________________________________________________________
# ReLU                 [1, 2048, 13, 13]    0          False
# ______________________________________________________________________
# Conv2d               [1, 2048, 13, 13]    2,097,152  False
# ______________________________________________________________________
# BatchNorm2d          [1, 2048, 13, 13]    4,096      True
# ______________________________________________________________________
# Conv2d               [1, 512, 13, 13]     1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 13, 13]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 512, 13, 13]     2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 13, 13]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 2048, 13, 13]    1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [1, 2048, 13, 13]    4,096      True
# ______________________________________________________________________
# ReLU                 [1, 2048, 13, 13]    0          False
# ______________________________________________________________________
# Conv2d               [1, 512, 13, 13]     1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 13, 13]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 512, 13, 13]     2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [1, 512, 13, 13]     1,024      True
# ______________________________________________________________________
# Conv2d               [1, 2048, 13, 13]    1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [1, 2048, 13, 13]    4,096      True
# ______________________________________________________________________
# ReLU                 [1, 2048, 13, 13]    0          False
# ______________________________________________________________________
# AvgPool2d            [1, 2048, 1, 1]      0          False
# ______________________________________________________________________
# Flatten              [1, 2048]            0          False
# ______________________________________________________________________
# BatchNorm1d          [1, 2048]            4,096      True
# ______________________________________________________________________
# Dropout              [1, 2048]            0          False
# ______________________________________________________________________
# Linear               [1, 512]             1,049,088  True
# ______________________________________________________________________
# ReLU                 [1, 512]             0          False
# ______________________________________________________________________
# BatchNorm1d          [1, 512]             1,024      True
# ______________________________________________________________________
# Dropout              [1, 512]             0          False
# ______________________________________________________________________
# Linear               [1, 128]             65,664     True
# ______________________________________________________________________
# ReLU                 [1, 128]             0          False
# ______________________________________________________________________
# BatchNorm1d          [1, 128]             256        True
# ______________________________________________________________________
# Dropout              [1, 128]             0          False
# ______________________________________________________________________
# Linear               [1, 1]               129        True
# ______________________________________________________________________
#
# Total params: 24,628,289
# Total trainable params: 1,173,377
# Total non-trainable params: 23,454,912

# %% [markdown]
# ## TRAIN

# %% [markdown]
# #### Helper functions

# %%
def plot_lr_find(learn):
    learn.lr_find()
    learn.recorder.plot()

# %%
def fit_one_cycle(learn, stage, n_epochs, max_lr):
    learn.fit_one_cycle(n_epochs, max_lr=max_lr, callbacks=[
        SaveModelCallback(learn,
                          monitor='mean_absolute_error',
                          mode='min',
                          every='improvement',
                          name=save_path/f'{version}-{stage}-best')])
    learn.recorder.plot_losses()
    learn.recorder.plot_lr(show_moms=True)

# %% [markdown]
# #### Stage 1.1

# %%
learn.freeze()

# %%
plot_lr_find(learn)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
stage = 's1.1'
n_epochs = 6
max_lr = slice(1.1e-2)

# %%
fit_one_cycle(learn, stage, n_epochs, max_lr)
# Out:
# Total time: 04:46 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_squared_error</th>
#       <th>mean_absolute_error</th>
#       <th>mse_scaled</th>
#       <th>mae_scaled</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.888015</td>
#       <td>2.370170</td>
#       <td>8.808948</td>
#       <td>2.370170</td>
#       <td>8.808948</td>
#       <td>2.370170</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.385308</td>
#       <td>2.172117</td>
#       <td>7.606056</td>
#       <td>2.172118</td>
#       <td>7.606056</td>
#       <td>2.172118</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.350336</td>
#       <td>2.295241</td>
#       <td>9.318892</td>
#       <td>2.295241</td>
#       <td>9.318892</td>
#       <td>2.295241</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.180888</td>
#       <td>2.204235</td>
#       <td>7.759037</td>
#       <td>2.204235</td>
#       <td>7.759037</td>
#       <td>2.204235</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.018347</td>
#       <td>2.194916</td>
#       <td>7.907675</td>
#       <td>2.194916</td>
#       <td>7.907675</td>
#       <td>2.194916</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.868078</td>
#       <td>2.220963</td>
#       <td>7.860903</td>
#       <td>2.220963</td>
#       <td>7.860903</td>
#       <td>2.220963</td>
#       <td>00:47</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with mean_absolute_error value: 2.3701698780059814.
# Better model found at epoch 1 with mean_absolute_error value: 2.1721179485321045.

# %% [markdown]
# #### Stage 1.2

# %%
learn.load(save_path/f'{version}-s1.1-best');

# %%
learn.freeze()

# %%
plot_lr_find(learn)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
stage = 's1.2'
n_epochs = 12
max_lr = slice(1e-4)

# %%
fit_one_cycle(learn, stage, n_epochs, max_lr)
# Out:
# Total time: 09:31 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_squared_error</th>
#       <th>mean_absolute_error</th>
#       <th>mse_scaled</th>
#       <th>mae_scaled</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.198311</td>
#       <td>2.183686</td>
#       <td>7.897193</td>
#       <td>2.183686</td>
#       <td>7.897193</td>
#       <td>2.183686</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.216074</td>
#       <td>2.186119</td>
#       <td>7.964037</td>
#       <td>2.186119</td>
#       <td>7.964037</td>
#       <td>2.186119</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.213560</td>
#       <td>2.185926</td>
#       <td>8.075896</td>
#       <td>2.185926</td>
#       <td>8.075896</td>
#       <td>2.185926</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.111046</td>
#       <td>2.163189</td>
#       <td>7.544728</td>
#       <td>2.163189</td>
#       <td>7.544728</td>
#       <td>2.163189</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.180923</td>
#       <td>2.155688</td>
#       <td>7.701450</td>
#       <td>2.155688</td>
#       <td>7.701450</td>
#       <td>2.155688</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.173878</td>
#       <td>2.150891</td>
#       <td>7.592803</td>
#       <td>2.150892</td>
#       <td>7.592803</td>
#       <td>2.150892</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.128716</td>
#       <td>2.161179</td>
#       <td>7.725159</td>
#       <td>2.161179</td>
#       <td>7.725159</td>
#       <td>2.161179</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.163655</td>
#       <td>2.163021</td>
#       <td>7.696402</td>
#       <td>2.163021</td>
#       <td>7.696402</td>
#       <td>2.163021</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.132270</td>
#       <td>2.155509</td>
#       <td>7.591424</td>
#       <td>2.155509</td>
#       <td>7.591424</td>
#       <td>2.155509</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.151557</td>
#       <td>2.168119</td>
#       <td>7.916059</td>
#       <td>2.168119</td>
#       <td>7.916059</td>
#       <td>2.168119</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.147784</td>
#       <td>2.166536</td>
#       <td>7.814484</td>
#       <td>2.166536</td>
#       <td>7.814484</td>
#       <td>2.166536</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.149055</td>
#       <td>2.156474</td>
#       <td>7.591887</td>
#       <td>2.156474</td>
#       <td>7.591887</td>
#       <td>2.156474</td>
#       <td>00:48</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with mean_absolute_error value: 2.183685779571533.
# Better model found at epoch 3 with mean_absolute_error value: 2.16318941116333.
# Better model found at epoch 4 with mean_absolute_error value: 2.1556878089904785.
# Better model found at epoch 5 with mean_absolute_error value: 2.1508915424346924.

# %% [markdown]
# #### Stage 2.1

# %%
learn.load(save_path/f'{version}-s1.2-best');

# %%
learn.unfreeze()

# %%
learn.lr_find(start_lr=1e-8)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
stage = 's2.1'
n_epochs = 6
max_lr = slice(4e-7, 4e-6)

# %%
fit_one_cycle(learn, stage, n_epochs, max_lr)
# Out:
# Total time: 06:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_squared_error</th>
#       <th>mean_absolute_error</th>
#       <th>mse_scaled</th>
#       <th>mae_scaled</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.183140</td>
#       <td>2.162655</td>
#       <td>7.722666</td>
#       <td>2.162655</td>
#       <td>7.722666</td>
#       <td>2.162655</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.182053</td>
#       <td>2.165921</td>
#       <td>7.683945</td>
#       <td>2.165921</td>
#       <td>7.683945</td>
#       <td>2.165921</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.132250</td>
#       <td>2.162801</td>
#       <td>7.784066</td>
#       <td>2.162801</td>
#       <td>7.784066</td>
#       <td>2.162801</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.078078</td>
#       <td>2.158149</td>
#       <td>7.646303</td>
#       <td>2.158149</td>
#       <td>7.646303</td>
#       <td>2.158149</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.041457</td>
#       <td>2.173215</td>
#       <td>7.895135</td>
#       <td>2.173215</td>
#       <td>7.895135</td>
#       <td>2.173215</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.022049</td>
#       <td>2.160106</td>
#       <td>7.587471</td>
#       <td>2.160106</td>
#       <td>7.587471</td>
#       <td>2.160106</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with mean_absolute_error value: 2.1626551151275635.
# Better model found at epoch 3 with mean_absolute_error value: 2.158149242401123.

# %% [markdown]
# #### Stage 2.2

# %%
learn.load(save_path/f'{version}-s2.1-best');

# %%
learn.unfreeze()

# %%
learn.lr_find(start_lr=1e-8)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
stage = 's2.2'
n_epochs = 24
max_lr = slice(2e-7, 2e-6)

# %%
fit_one_cycle(learn, stage, n_epochs, max_lr)
# Out:
# Total time: 26:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mean_squared_error</th>
#       <th>mean_absolute_error</th>
#       <th>mse_scaled</th>
#       <th>mae_scaled</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.060691</td>
#       <td>2.161368</td>
#       <td>7.687799</td>
#       <td>2.161368</td>
#       <td>7.687799</td>
#       <td>2.161368</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.018611</td>
#       <td>2.164892</td>
#       <td>7.732878</td>
#       <td>2.164892</td>
#       <td>7.732878</td>
#       <td>2.164892</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.063131</td>
#       <td>2.157745</td>
#       <td>7.621726</td>
#       <td>2.157745</td>
#       <td>7.621726</td>
#       <td>2.157745</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.048099</td>
#       <td>2.162569</td>
#       <td>7.763922</td>
#       <td>2.162568</td>
#       <td>7.763922</td>
#       <td>2.162568</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.017438</td>
#       <td>2.171033</td>
#       <td>7.857278</td>
#       <td>2.171033</td>
#       <td>7.857278</td>
#       <td>2.171033</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.019574</td>
#       <td>2.169889</td>
#       <td>7.903653</td>
#       <td>2.169889</td>
#       <td>7.903653</td>
#       <td>2.169889</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.017973</td>
#       <td>2.160876</td>
#       <td>7.794072</td>
#       <td>2.160875</td>
#       <td>7.794072</td>
#       <td>2.160875</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.017489</td>
#       <td>2.171536</td>
#       <td>7.908830</td>
#       <td>2.171536</td>
#       <td>7.908830</td>
#       <td>2.171536</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.935734</td>
#       <td>2.174280</td>
#       <td>7.839408</td>
#       <td>2.174281</td>
#       <td>7.839408</td>
#       <td>2.174281</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.004815</td>
#       <td>2.176523</td>
#       <td>7.942178</td>
#       <td>2.176523</td>
#       <td>7.942178</td>
#       <td>2.176523</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.862149</td>
#       <td>2.212631</td>
#       <td>8.432036</td>
#       <td>2.212631</td>
#       <td>8.432036</td>
#       <td>2.212631</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.847895</td>
#       <td>2.178691</td>
#       <td>7.878092</td>
#       <td>2.178691</td>
#       <td>7.878092</td>
#       <td>2.178691</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.908053</td>
#       <td>2.193662</td>
#       <td>8.121584</td>
#       <td>2.193662</td>
#       <td>8.121584</td>
#       <td>2.193662</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.821399</td>
#       <td>2.199677</td>
#       <td>8.116281</td>
#       <td>2.199677</td>
#       <td>8.116281</td>
#       <td>2.199677</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.844330</td>
#       <td>2.197571</td>
#       <td>8.085941</td>
#       <td>2.197571</td>
#       <td>8.085941</td>
#       <td>2.197571</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.834320</td>
#       <td>2.207795</td>
#       <td>8.162808</td>
#       <td>2.207795</td>
#       <td>8.162808</td>
#       <td>2.207795</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.845822</td>
#       <td>2.206014</td>
#       <td>8.231814</td>
#       <td>2.206014</td>
#       <td>8.231814</td>
#       <td>2.206014</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.769732</td>
#       <td>2.215043</td>
#       <td>8.262401</td>
#       <td>2.215042</td>
#       <td>8.262401</td>
#       <td>2.215042</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.808622</td>
#       <td>2.210660</td>
#       <td>8.125579</td>
#       <td>2.210660</td>
#       <td>8.125579</td>
#       <td>2.210660</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.756907</td>
#       <td>2.219737</td>
#       <td>7.974630</td>
#       <td>2.219737</td>
#       <td>7.974630</td>
#       <td>2.219737</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.762221</td>
#       <td>2.216806</td>
#       <td>8.080973</td>
#       <td>2.216807</td>
#       <td>8.080973</td>
#       <td>2.216807</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.697920</td>
#       <td>2.210594</td>
#       <td>8.107426</td>
#       <td>2.210594</td>
#       <td>8.107426</td>
#       <td>2.210594</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.721206</td>
#       <td>2.216559</td>
#       <td>8.081117</td>
#       <td>2.216558</td>
#       <td>8.081117</td>
#       <td>2.216558</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.859674</td>
#       <td>2.221839</td>
#       <td>8.404282</td>
#       <td>2.221838</td>
#       <td>8.404282</td>
#       <td>2.221838</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with mean_absolute_error value: 2.1613681316375732.
# Better model found at epoch 2 with mean_absolute_error value: 2.157744884490967.

# %% [markdown]
# ## RESULTS

# %%
learn.load(save_path/f'{version}-s2.2-best');

# %%
# plot histograms of results
def plot_results(dataset):
    preds, targs = learn.get_preds(ds_type=dataset)
    preds = preds * scale
    targs = targs * scale
    print('min/max pred: ', min(preds).item(), max(preds).item())
    print('min/max targ: ', min(targs).item(), max(targs).item())
    fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(nrows=2, ncols=2, figsize=(18, 12))
    ax1.hist(preds.squeeze(), bins=50); ax1.set_xlabel('TTF'); ax1.set_ylabel('preds')
    ax2.plot(preds); ax2.set_xlabel('segment')
    ax3.hist(targs, bins=50); ax3.set_xlabel('TTF'); ax3.set_ylabel('targs')
    ax4.plot(targs); ax4.set_xlabel('segment')

# %% [markdown]
# #### Training Set

# %%
plot_results(DatasetType.Fix)
# Out:
# min/max pred:  -2.847398281097412 11.638466835021973
# min/max targ:  0.006397657096385956 16.103195190429688

# %% [markdown]
# #### Validation Set

# %%
plot_results(DatasetType.Valid)
# Out:
# min/max pred:  -2.9317164421081543 10.410432815551758
# min/max targ:  0.0072983005084097385 15.634998321533203

# %% [markdown]
# #### Test Set

# %%
plot_results(DatasetType.Test)
# Out:
# min/max pred:  -3.62943696975708 10.791540145874023
# min/max targ:  0.0 0.0

# %% [markdown]
# ## SUBMISSION

# %%
test_preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
# load sample submission
submission = pd.read_csv(path/'sample_submission.csv', index_col='seg_id')

# %%
# assume order of test set is unchanged
submission['time_to_failure'] = [test_preds[i].item() * scale for i in range(len(test_preds))]

# %%
submission.head()
# Out:
#             time_to_failure
# seg_id
# seg_00030f         4.470489
# seg_0012b5         6.559947
# seg_00184e         5.003995
# seg_003339         8.326233
# seg_0042cc         5.712809

# %%
submission_file = path/f'{version}-submission.csv'
submission.to_csv(submission_file)

# %%
# submit to leaderboard
! cd $path; kaggle competitions submit -c LANL-Earthquake-Prediction -f $submission_file -m "Message"
# Out:
# 100%|██████████████████████████████████████| 74.9k/74.9k [00:06<00:00, 11.0kB/s]
# Successfully submitted to LANL Earthquake Prediction
